# %%
import pandas as pd
from sqlalchemy import create_engine
from sklearn.linear_model import LinearRegression
import numpy as np
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource
import unittest

# %%
class DataManager:
    def __init__(self, database_url):
        self.engine = create_engine(database_url)
        self.connect_database()

    def connect_database(self):
        # Connect to the SQLite database
        self.connection = self.engine.connect()

    def close_database(self):
        # Close the database connection
        self.connection.close()

    def load_data_to_database(self, data, table_name):
        # Load data to the specified table in the database
        data.to_sql(table_name, con=self.connection, index=False, if_exists='replace')

    def load_DataFrame(self):
        # Load training data from CSV to a Pandas DataFrame
        test_df = pd.read_csv('test.csv')
        train_df = pd.read_csv('train.csv')
        ideal_df = pd.read_csv('ideal.csv')

    def load_ideal_functions(self, ideal_functions_path):
        # Load ideal functions from CSV to a Pandas DataFrame
        ideal_functions = pd.read_csv(ideal_functions_path)
        # Assume ideal_functions has columns ['x', 'func1', 'func2', 'func3', 'func4']
        self.load_data_to_database(ideal_functions, 'ideal_functions')

# %% [markdown]
# <div style="color:#FBDC8A; font-family: Calibri; font-size: 16pt; text-align: center;">
#      <strong>Train Test Split<strong> </div>
#     <em>Now let's split the data into a training set and a testing set. We will train out model on the training set and then use the test set to evaluate the model.<em>
#     </div>

# %% [markdown]
# <div style="color:#FBDC8A; font-family: Calibri; font-size: 16pt; text-align: center;">
#      <strong>Check If Data Frames Created<strong> </div>
#     <em>Monitoring the first 5 rows of dataframes if they are built<em>
#     </div>

# %%
test_df.head()
# Out:
#       x          y
# 0  17.5  34.161040
# 1   0.3   1.215102
# 2  -8.7 -16.843908
# 3 -19.2 -37.170870
# 4 -11.0 -20.263054

# %%
train_df.head()
# Out:
#       x         y1         y2         y3        y4
# 0 -20.0  39.778572 -40.078590 -20.214268 -0.324914
# 1 -19.9  39.604813 -39.784000 -20.070950 -0.058820
# 2 -19.8  40.099070 -40.018845 -19.906782 -0.451830
# 3 -19.7  40.151100 -39.518402 -19.389118 -0.612044
# 4 -19.6  39.795662 -39.360065 -19.815890 -0.306076

# %%
ideal_df.head()
# Out:
#       x        y1        y2        y3        y4        y5        y6        y7  \
# 0 -20.0 -0.912945  0.408082  9.087055  5.408082 -9.087055  0.912945 -0.839071
# 1 -19.9 -0.867644  0.497186  9.132356  5.497186 -9.132356  0.867644 -0.865213
# 2 -19.8 -0.813674  0.581322  9.186326  5.581322 -9.186326  0.813674 -0.889191
# 3 -19.7 -0.751573  0.659649  9.248426  5.659649 -9.248426  0.751573 -0.910947
# 4 -19.6 -0.681964  0.731386  9.318036  5.731386 -9.318036  0.681964 -0.930426
#
#          y8        y9  ...        y41        y42       y43       y44  \
# 0 -0.850919  0.816164  ... -40.456474  40.204040  2.995732 -0.008333
# 1  0.168518  0.994372  ... -40.233820  40.048590  2.990720 -0.008340
# 2  0.612391  1.162644  ... -40.006836  39.890660  2.985682 -0.008347
# 3 -0.994669  1.319299  ... -39.775787  39.729824  2.980619 -0.008354
# 4  0.774356  1.462772  ... -39.540980  39.565693  2.975530 -0.008361
#
#          y45       y46       y47       y48       y49       y50
# ...
