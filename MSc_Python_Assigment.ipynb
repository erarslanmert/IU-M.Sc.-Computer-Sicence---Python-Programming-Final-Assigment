# %%
import pandas as pd
from sqlalchemy import create_engine, Column, Integer, Float, MetaData, Table
from sqlalchemy.orm import sessionmaker
import numpy as np
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource
from bokeh.layouts import gridplot
from bokeh.models import ColumnDataSource, DataTable, TableColumn, HTMLTemplateFormatter
from bokeh.io import output_notebook, show
import unittest
import sqlite3
from sklearn.metrics import mean_squared_error

# %% [markdown]
# <div style="color:#FBDC8A; font-family: Calibri; font-size: 16pt; text-align: center;">
#      <strong>Building Database and DataFrame <strong> </div>
#         <em> Let's create a database with three tables reflecting data shared in the assigment and split the data into a training set and a testing set. We will train out model on the training set and then use the test set to evaluate the model.<em>
#     </div>

# %%
class DataManager:
    def __init__(self, database_path):
        self.engine = create_engine(database_path)
        self.metadata = MetaData(bind=self.engine)
        self.Session = sessionmaker(bind=self.engine)
        self.metadata.create_all()

    def create_tables(self, train_file, test_file, ideal_file):
        # Load DataFrames
        train_df = pd.read_csv(train_file)
        test_df = pd.read_csv(test_file)
        ideal_df = pd.read_csv(ideal_file)

        # Define table structures
        train_table = Table('train', self.metadata,
                           Column('x', Float),
                           Column('y', Float),
                           )

        test_table = Table('test', self.metadata,
                          Column('x', Float),
                          Column('y', Float),
                          )

        ideal_table = Table('ideal', self.metadata,
                           Column('x', Float),
                           Column('y', Float),
                           )

        # Create a session to insert data
        session = self.Session()

        try:
            # Insert data into 'train' table
            train_df.to_sql('train', con=self.engine, if_exists='replace', index=False)

            # Insert data into 'test' table
            test_df.to_sql('test', con=self.engine, if_exists='replace', index=False)

            # Insert data into 'ideal' table
            ideal_df.to_sql('ideal', con=self.engine, if_exists='replace', index=False)

            # Commit the changes
            session.commit()

        except Exception as e:
            print(f"Error: {e}")
            # Rollback in case of error
            session.rollback()

        finally:
            # Close the session
            session.close()

# Example usage:
# Assuming you have file paths for train, test, and ideal CSV files
train_file = 'train.csv'
test_file = 'test.csv'
ideal_file = 'ideal.csv'
database_path = "sqlite:///data.db"  # Change this to your desired database file path

data_manager = DataManager(database_path)
data_manager.create_tables(train_file, test_file, ideal_file)

# %% [markdown]
# <div style="color:#FBDC8A; font-family: Calibri; font-size: 16pt; text-align: center;">
#      <strong>Check If Database and Data Frames Created<strong> </div>
#     <em>Checking which tables, which columns and what type of values in rows exist in SQLite database and monitoring the first 5 rows of dataframes if they are built for our training model<em>
#     </div>

# %%
class DataVisualizer(DataManager):
    def get_table_info(self):
        # Reflect the tables from the database
        self.metadata.reflect()

        # Display general information about each table
        for table_name, table in self.metadata.tables.items():
            print(f"\nTable: {table_name}")

            # Get the column names and their data types
            columns = table.columns

            # Display column information
            print("Column Name\tData Type")
            print("-------------------------")
            for column in columns:
                print(f"{column.name}\t\t{column.type}")
    
    def draw_train_functions(self):
        # Create a Bokeh figure for training functions
        # Create a list to store Bokeh figures
        figures = []

        # Create a Bokeh figure for each function
        for i, column in enumerate(train_df.columns[1:]):  # Skip the 'x' column
            p = figure(title=f"Function {i + 1}", x_axis_label="x", y_axis_label=f"y{i + 1}")
            p.line(train_df['x'], train_df[column], line_width=1, line_color="blue", legend_label=f'Function {i + 1}')
            figures.append(p)

        # Arrange figures in a grid
        grid = gridplot([figures])

        # Show the grid
        show(grid)
    
    def draw_ideal_functions(self):
        # Create a Bokeh figure for ideal functions
        # Define the number of rows and columns in the grid
        num_rows, num_cols = 10, 5

        # Calculate the number of sketches in the last column
        sketches_in_last_col = len(ideal_df.columns[1:]) % num_cols

        # Create a list to store Bokeh figures
        figures = []

        # Create a Bokeh figure for each function
        for i, column in enumerate(ideal_df.columns[1:]):  # Skip the 'x' column
            row_idx, col_idx = divmod(i, num_cols)
            p = figure(title=f"Function {i + 1}", x_axis_label="x", y_axis_label=f"y{i + 1}")
            p.line(ideal_df['x'], ideal_df[column], line_width=4, line_color="blue", legend_label=f'Function {i + 1}')
            figures.append((p, row_idx, col_idx))

        # If the last column has only one sketch, add an empty plot to fill the space
        if sketches_in_last_col == 1:
            figures.append((figure(), num_rows - 1, num_cols - 1))

        # Arrange figures in a grid
        grid = gridplot([[figures[i * num_cols + j][0] for j in range(num_cols)] for i in range(num_rows)])

        # Show the grid
        show(grid)
        
    def draw_ideal_and_train_fit(self):
        # Create a Bokeh figure for ideal and training functions
        num_rows, num_cols = 10, 5
        sketches_in_last_col = len(ideal_df.columns[1:]) % num_cols
        figures = []

        # Create a Bokeh figure for each function
        for i, column in enumerate(ideal_df.columns[1:]):  # Skip the 'x' column
            row_idx, col_idx = divmod(i, num_cols)
            p = figure(title=f"Function {i + 1}", x_axis_label="x", y_axis_label=f"y{i + 1}")

            # Plot ideal function
            p.line(ideal_df['x'], ideal_df[column], line_width=4, line_color="blue", legend_label=f'Ideal Function {i + 1}')

            # Plot corresponding training functions
            colors = ['green', 'yellow', 'red', 'orange']
            count = 0
            for train_column in train_df.columns[1:]: 
                # Skip the 'x' column
                p.line(train_df['x'], train_df[train_column], line_width=2, line_color=colors[count], legend_label=f'Train Function {train_column[-1]}')
                count = count + 1
                
            figures.append((p, row_idx, col_idx))

        # If the last column has only one sketch, add an empty plot to fill the space
        if sketches_in_last_col == 1:
            figures.append((figure(), num_rows - 1, num_cols - 1))

        # Arrange figures in a grid
        grid = gridplot([[figures[i * num_cols + j][0] for j in range(num_cols)] for i in range(num_rows)])

        # Show the grid
        show(grid)
        
    def draw_test_function():
        # Create a Bokeh figure for training functions
        # Create a list to store Bokeh figures
        figures = []

        # Create a Bokeh figure for each function
        for i, column in enumerate(test_df.columns[1:]):  # Skip the 'x' column
            p = figure(title=f"Function {i + 1}", x_axis_label="x", y_axis_label=f"y{i + 1}")
            p.line(train_df['x'], train_df[column], line_width=1, line_color="blue", legend_label=f'Function {i + 1}')
            figures.append(p)

        # Arrange figures in a grid
        grid = gridplot([figures])

        # Show the grid
        show(grid)
        
    def summerize_db(self):
        # Connect to the SQLite database
        conn = sqlite3.connect('data.db')
        cursor = conn.cursor()

        # Get the list of tables in the database
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()

        # Iterate through each table
        for table in tables:
            table_name = table[0]

            # Get the number of rows in the table
            cursor.execute(f"SELECT COUNT(*) FROM {table_name};")
            num_rows = cursor.fetchone()[0]

            # Get the number of columns in the table
            cursor.execute(f"PRAGMA table_info({table_name});")
            columns = cursor.fetchall()
            num_columns = len(columns)

            # Print information about the table
            print(f"Table: {table_name}, Rows: {num_rows}, Columns: {num_columns}")

        # Close the connection
        conn.close()
        
train_file = 'train.csv'
test_file = 'test.csv'
ideal_file = 'ideal.csv'
database_path = "sqlite:///data.db" 

data_manager = DataManager(database_path)
data_manager.create_tables(train_file, test_file, ideal_file)

# Create DataVisualizer instance
data_visualizer = DataVisualizer(database_path)
data_visualizer.get_table_info()
# Out:
# Table: MSE
# Column Name	Data Type
# -------------------------
# Train_Function		NULL
# Ideal_Function		NULL
# MSE		NULL
#
# Table: ideal
# Column Name	Data Type
# -------------------------
# x		FLOAT
# y1		FLOAT
# y2		FLOAT
# y3		FLOAT
# y4		FLOAT
# y5		FLOAT
# y6		FLOAT
# y7		FLOAT
# y8		FLOAT
# y9		FLOAT
# y10		FLOAT
# y11		FLOAT
# y12		FLOAT
# y13		FLOAT
# y14		FLOAT
# y15		FLOAT
# y16		FLOAT
# y17		FLOAT
# y18		FLOAT
# y19		FLOAT
# y20		FLOAT
# y21		FLOAT
# y22		FLOAT
# y23		FLOAT
# y24		FLOAT
# y25		FLOAT
# y26		FLOAT
# y27		FLOAT
# y28		FLOAT
# y29		FLOAT
# y30		FLOAT
# y31		FLOAT
# y32		FLOAT
# y33		FLOAT
# y34		FLOAT
# y35		FLOAT
# y36		FLOAT
# y37		FLOAT
# y38		FLOAT
# y39		FLOAT
# y40		FLOAT
# y41		FLOAT
# y42		FLOAT
# y43		FLOAT
# y44		FLOAT
# y45		FLOAT
# y46		FLOAT
# y47		FLOAT
# y48		FLOAT
# y49		FLOAT
# y50		FLOAT
#
# Table: test
# Column Name	Data Type
# -------------------------
# x		FLOAT
# y		FLOAT
#
# Table: train
# Column Name	Data Type
# -------------------------
# x		FLOAT
# y1		FLOAT
# y2		FLOAT
# y3		FLOAT
# y4		FLOAT

# %%
test_df.head()
# Out:
#       x          y
# 0  17.5  34.161040
# 1   0.3   1.215102
# 2  -8.7 -16.843908
# 3 -19.2 -37.170870
# 4 -11.0 -20.263054

# %%
train_df.head()
# Out:
#       x         y1         y2         y3        y4
# 0 -20.0  39.778572 -40.078590 -20.214268 -0.324914
# 1 -19.9  39.604813 -39.784000 -20.070950 -0.058820
# 2 -19.8  40.099070 -40.018845 -19.906782 -0.451830
# 3 -19.7  40.151100 -39.518402 -19.389118 -0.612044
# 4 -19.6  39.795662 -39.360065 -19.815890 -0.306076

# %%
ideal_df.head()
# Out:
#       x        y1        y2        y3        y4        y5        y6        y7  \
# 0 -20.0 -0.912945  0.408082  9.087055  5.408082 -9.087055  0.912945 -0.839071
# 1 -19.9 -0.867644  0.497186  9.132356  5.497186 -9.132356  0.867644 -0.865213
# 2 -19.8 -0.813674  0.581322  9.186326  5.581322 -9.186326  0.813674 -0.889191
# 3 -19.7 -0.751573  0.659649  9.248426  5.659649 -9.248426  0.751573 -0.910947
# 4 -19.6 -0.681964  0.731386  9.318036  5.731386 -9.318036  0.681964 -0.930426
#
#          y8        y9  ...        y41        y42       y43       y44  \
# 0 -0.850919  0.816164  ... -40.456474  40.204040  2.995732 -0.008333
# 1  0.168518  0.994372  ... -40.233820  40.048590  2.990720 -0.008340
# 2  0.612391  1.162644  ... -40.006836  39.890660  2.985682 -0.008347
# 3 -0.994669  1.319299  ... -39.775787  39.729824  2.980619 -0.008354
# 4  0.774356  1.462772  ... -39.540980  39.565693  2.975530 -0.008361
#
#          y45       y46       y47       y48       y49       y50
# 0  12.995732  5.298317 -5.298317 -0.186278  0.912945  0.396850
# 1  12.990720  5.293305 -5.293305 -0.215690  0.867644  0.476954
# 2  12.985682  5.288267 -5.288267 -0.236503  0.813674  0.549129
# 3  12.980619  5.283204 -5.283204 -0.247887  0.751573  0.612840
# 4  12.975530  5.278115 -5.278115 -0.249389  0.681964  0.667902
#
# [5 rows x 51 columns]

# %% [markdown]
# <div style="color:#FBDC8A; font-family: Calibri; font-size: 16pt; text-align: center;">
#      <strong>Exploratory Data Analysis for Data Sets<strong> </div>
#     <em>Let's dig into data sets and visualize them in order to have better insight, so that we can select an optimum method to train our model.<em>
#     </div>

# %%
data_visualizer.draw_train_functions()

# %% [markdown]
# <div style="color:#FBDC8A; font-family: Calibri; font-size: 16pt; text-align: center;">
#      <strong>Plots created for training functions<strong> </div>
#
#
# ![Alt text](bokeh_plot.png)

# %%
data_visualizer.draw_ideal_functions()

# %% [markdown]
# <div style="color:#FBDC8A; font-family: Calibri; font-size: 16pt; text-align: center;">
#      <strong>Plots created for ideal functions<strong> </div>
#
#
# ![Alt text](bokeh_plot(1).png)

# %%
data_visualizer.draw_ideal_and_train_fit()

# %% [markdown]
# <div style="color:#FBDC8A; font-family: Calibri; font-size: 16pt; text-align: center;">
#      <strong>Plots created for ideal functions vs train functions and their fit<strong> </div>
#
#
# ![Alt text](bokeh_plot(2).png)

# %% [markdown]
# <div style="color:#FBDC8A; font-family: Calibri; font-size: 16pt; text-align: center;">
#      <strong>Best Fit Selection - Optimization <strong> </div>
#         <em> Now we clearly see how the functions seem and how likely tehy fit each other. Right now, we can easily decide which models best fit on the figure above to each other, for each four train function. The only thing we can support our choices for those functions, to evaluate how similar those fitting functions by using some deviation optimization, if the final report matches with our visual observation, we can definetely say that, we have selected the best ideal function for our train functions. We will use two different approach to to define regression parameters, is going to be mean square error in between training functions and ideal functions. <em>
#     </div>

# %%
class FunctionSelector:
    def __init__(self):
        self.train_df = train_df
        self.ideal_df = ideal_df
        self.fit_results = []
    # Measure mean square error for every single train functions with every single ideal functions
    def measure_fit(self):
        self.fit_results = []
        # Iterate over each train function
        for train_column in self.train_df.columns[1:]:  # Assuming the first column is 'x'
            train_function = self.train_df[train_column]

            # Iterate over each ideal function
            for ideal_column in self.ideal_df.columns[1:]:  # Assuming the first column is 'x'
                ideal_function = self.ideal_df[ideal_column]

                # Calculate MSE for the pair of train and ideal functions
                mse = mean_squared_error(train_function, ideal_function)

                # Append the result to the fit_results list
                self.fit_results.append({
                    'Train_Function': train_column,
                    'Ideal_Function': ideal_column,
                    'MSE': mse
                })

        return self.fit_results
    
    def delete_table(self,table_name):
        # Connect to the SQLite database
        conn = sqlite3.connect('data.db')
        cursor = conn.cursor()

        # Check if the table exists
        cursor.execute(f"SELECT name FROM sqlite_master WHERE type='table' AND name=?;", (table_name,))
        existing_table = cursor.fetchone()

        # If the table exists, delete it
        if existing_table:
            cursor.execute(f"DROP TABLE {table_name};")
            print(f"The table '{table_name}' has been deleted.")
        else:
            print(f"The table '{table_name}' does not exist. No action taken.")

        # Commit the changes and close the connection
        conn.commit()
        conn.close()
    
    def save_result_SQLite_db(self):
        # Connect to the SQLite database
        self.delete_table('MSE')
        conn = sqlite3.connect('data.db')
        cursor = conn.cursor()
        
        # Create the 'MSE' table if it doesn't exist
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS MSE (
                Train_Function,
                Ideal_Function,
                MSE
            )
        ''')
        
        # Extract data from the list and insert it into the 'MSE' table
        for result in self.fit_results:
            cursor.execute('INSERT INTO MSE VALUES (?, ?, ?)',
                           (result['Train_Function'], result['Ideal_Function'], result['MSE']))
        # Commit the changes and close the connection
        conn.commit()
        conn.close()
        
    def list_minimum_MSE(self):
        # Connect to the SQLite database
        conn = sqlite3.connect('data.db')
        cursor = conn.cursor()

        # SQL query to select rows with the smallest MSE values for each unique Train_Function
        query = '''
            SELECT Train_Function, Ideal_Function, MIN(MSE) AS MinMSE
            FROM MSE
            GROUP BY Train_Function
        '''

        # Execute the query
        cursor.execute(query)

        # Fetch the results
        results = cursor.fetchall()

        # Print the results
        for row in results:
            print(f"Train_Function: {row[0]}, Ideal_Function: {row[1]}, MinMSE: {row[2]}")

        # Close the connection
        conn.close()

# %% [markdown]
# <div style="color:#FBDC8A; font-family: Calibri; font-size: 16pt; text-align: center;">
#      <strong>Check If we computed the MSE values and saved them to new table on SQLite database <strong> </div>

# %%
function_selector = FunctionSelector()
function_selector.measure_fit()
# Out:
# [{'Train_Function': 'y1', 'Ideal_Function': 'y1', 'MSE': 531.4721758281776},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y2', 'MSE': 532.3463685083657},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y3', 'MSE': 629.2732085913425},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y4', 'MSE': 556.7258002213116},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y5', 'MSE': 636.4949061984047},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y6', 'MSE': 534.3872334237362},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y7', 'MSE': 533.1589637469536},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y8', 'MSE': 533.156887328273},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y9', 'MSE': 533.2723152357476},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y10', 'MSE': 591.9874779190924},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y11', 'MSE': 1198.5542619682105},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y12', 'MSE': 3333.7641467090225},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y13', 'MSE': 2158.416197078326},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y14', 'MSE': 132.99371298082846},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y15', 'MSE': 307.88660385781895},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y16', 'MSE': 32444.079405890152},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y17', 'MSE': 32623.465229058882},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y18', 'MSE': 128358.38648430583},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y19', 'MSE': 35208.62608465731},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y20', 'MSE': 42674.51306374274},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y21', 'MSE': 9272015.574502436},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y22', 'MSE': 9142369.528751988},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y23', 'MSE': 9016363.575853515},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y24', 'MSE': 36830812.9823984},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y25', 'MSE': 82676348.97579105},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y26', 'MSE': 11130803.857469868},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y27', 'MSE': 11060784.332233096},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y28', 'MSE': 9336684.35643693},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y29', 'MSE': 9287927.214920852},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y30', 'MSE': 9429357.51698499},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y31', 'MSE': 661.4104691123305},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y32', 'MSE': 541.4913166824108},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y33', 'MSE': 666.350106690553},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y34', 'MSE': 531.8093918594191},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y35', 'MSE': 563.5637903451805},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y36', 'MSE': 3843.9963956635747},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y37', 'MSE': 670.1375058367084},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y38', 'MSE': 532.5852233363657},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y39', 'MSE': 32441.28660431971},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y40', 'MSE': 112721.1752279897},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y41', 'MSE': 2130.0093359529737},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y42', 'MSE': 0.08561648575842126},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y43', 'MSE': 538.9073259209491},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y44', 'MSE': 532.3867444056948},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y45', 'MSE': 675.4312622238},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y46', 'MSE': 552.6191713423726},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y47', 'MSE': 554.7240460573962},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y48', 'MSE': 532.8167893659872},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y49', 'MSE': 532.745277460722},
#  {'Train_Function': 'y1', 'Ideal_Function': 'y50', 'MSE': 532.2959331118492},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y1', 'MSE': 534.2688649498335},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y2', 'MSE': 533.4205592263925},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y3', 'MSE': 636.1079973427409},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y4', 'MSE': 559.819041960539},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y5', 'MSE': 630.4391906407379},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y6', 'MSE': 532.3696174958119},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y7', 'MSE': 533.1974112883518},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y8', 'MSE': 533.1543531369839},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y9', 'MSE': 535.0311600727989},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y10', 'MSE': 599.2941352216639},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y11', 'MSE': 133.18707537150777},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y12', 'MSE': 137.69113414150277},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y13', 'MSE': 25.273236247255262},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y14', 'MSE': 1199.1399727712626},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y15', 'MSE': 842.365932675949},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y16', 'MSE': 32613.203328036183},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y17', 'MSE': 32455.120380106586},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y18', 'MSE': 128696.24479200099},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y19', 'MSE': 35381.788108884924},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y20', 'MSE': 36452.730938600784},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y21', 'MSE': 9016236.45356004},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y22', 'MSE': 9145766.772299433},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y23', 'MSE': 9272143.475869104},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y24', 'MSE': 36319254.350977},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y25', 'MSE': 81909012.85144453},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y26', 'MSE': 10863251.292644108},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y27', 'MSE': 11330368.949721973},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y28', 'MSE': 9079839.478771338},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y29', 'MSE': 9032316.828364003},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y30', 'MSE': 9173242.946322532},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y31', 'MSE': 670.0908114902828},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y32', 'MSE': 543.6937831929023},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y33', 'MSE': 675.1141857021421},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y34', 'MSE': 534.6953057344158},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y35', 'MSE': 568.2060306415327},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y36', 'MSE': 3885.8399611658724},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y37', 'MSE': 662.2362366524877},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y38', 'MSE': 534.6972582042491},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y39', 'MSE': 32612.817653793638},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y40', 'MSE': 134245.1299565239},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y41', 'MSE': 0.0890046173120288},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y42', 'MSE': 2132.330927733377},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y43', 'MSE': 540.4543199461931},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y44', 'MSE': 532.8812759611644},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y45', 'MSE': 681.0163582067886},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y46', 'MSE': 555.0959727445137},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y47', 'MSE': 553.0263178489869},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y48', 'MSE': 532.5156161964436},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y49', 'MSE': 533.4796780069831},
#  {'Train_Function': 'y2', 'Ideal_Function': 'y50', 'MSE': 533.3040577437071},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y1', 'MSE': 134.51453928272113},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y2', 'MSE': 133.876070204425},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y3', 'MSE': 235.5014575733077},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y4', 'MSE': 159.84844558783064},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y5', 'MSE': 232.01005134377135},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y6', 'MSE': 133.0882640965245},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y7', 'MSE': 133.75776145608538},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y8', 'MSE': 133.72255951168742},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y9', 'MSE': 135.46002156198912},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y10', 'MSE': 198.28731892780445},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y11', 'MSE': 0.07465457572540955},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y12', 'MSE': 537.2191078765553},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y13', 'MSE': 158.9923415488904},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y14', 'MSE': 533.2167145006455},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y15', 'MSE': 309.3897193580404},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y16', 'MSE': 32177.668597817134},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y17', 'MSE': 32091.61943125924},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y18', 'MSE': 128224.69317109609},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y19', 'MSE': 34945.40116394588},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y20', 'MSE': 37614.861727558244},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y21', 'MSE': 9079809.25096084},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y22', 'MSE': 9144654.068437347},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y23', 'MSE': 9207771.642789237},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y24', 'MSE': 36446799.463618144},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y25', 'MSE': 82100529.85359803},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y26', 'MSE': 10929804.171953866},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y27', 'MSE': 11262583.468501363},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y28', 'MSE': 9143678.681590877},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y29', 'MSE': 9095853.608874118},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y30', 'MSE': 9236887.351397347},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y31', 'MSE': 268.76401121920543},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y32', 'MSE': 143.77701399729244},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y33', 'MSE': 273.7794657935455},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y34', 'MSE': 134.89742199480634},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y35', 'MSE': 167.7314450904554},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y36', 'MSE': 3477.2773179432857},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y37', 'MSE': 264.5273578571654},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y38', 'MSE': 134.96958206070948},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y39', 'MSE': 32177.046443497566},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y40', 'MSE': 128472.99135991972},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y41', 'MSE': 133.26375889562033},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y42', 'MSE': 1199.9889256700312},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y43', 'MSE': 140.65349590180955},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y44', 'MSE': 133.3370269953158},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y45', 'MSE': 280.3633194700335},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y46', 'MSE': 155.09891900136066},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y47', 'MSE': 153.98769252574004},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y48', 'MSE': 133.16921537185533},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y49', 'MSE': 133.89107850025758},
#  {'Train_Function': 'y3', 'Ideal_Function': 'y50', 'MSE': 133.75941783149864},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y1', 'MSE': 0.5520483670755024},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y2', 'MSE': 0.6140097883451564},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y3', 'MSE': 100.25374498810739},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y4', 'MSE': 25.943774041241703},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y5', 'MSE': 100.85011895709806},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y6', 'MSE': 0.6431100402965338},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y7', 'MSE': 0.6141858101569482},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y8', 'MSE': 0.5757693206794393},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y9', 'MSE': 2.139723216359371},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y10', 'MSE': 63.06030413032661},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y11', 'MSE': 133.07332569561876},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y12', 'MSE': 1202.3657217524153},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y13', 'MSE': 558.8361174138485},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y14', 'MSE': 133.81039840887843},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y15', 'MSE': 42.699083385647825},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y16', 'MSE': 32001.50278342494},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y17', 'MSE': 32001.377600679556},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y18', 'MSE': 128005.56536479764},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y19', 'MSE': 34767.950127275224},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y20', 'MSE': 39034.75417475042},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y21', 'MSE': 9143504.349415362},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y22', 'MSE': 9143674.559778685},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y23', 'MSE': 9143810.136689743},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y24', 'MSE': 36574322.86434967},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y25', 'MSE': 82291880.91437128},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y26', 'MSE': 10996434.900202401},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y27', 'MSE': 11195168.732349338},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y28', 'MSE': 9207639.982539006},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y29', 'MSE': 9159505.745336736},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y30', 'MSE': 9300667.731224542},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y31', 'MSE': 133.34691418254835},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y32', 'MSE': 10.060748858786669},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y33', 'MSE': 138.32459468325982},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y34', 'MSE': 0.9146338862089692},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y35', 'MSE': 33.599570332267376},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y36', 'MSE': 3333.0071227037474},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y37', 'MSE': 133.53680992194884},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y38', 'MSE': 1.0653291101136444},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y39', 'MSE': 32000.121966772767},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y40', 'MSE': 122959.98169482863},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y41', 'MSE': 532.0855889122489},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y42', 'MSE': 534.3509967049396},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y43', 'MSE': 7.124998881022534},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y44', 'MSE': 0.10725709689920797},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y45', 'MSE': 145.54960021846802},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y46', 'MSE': 21.274488615182598},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y47', 'MSE': 21.404477940044508},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y48', 'MSE': 0.07990858581972925},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y49', 'MSE': 0.5809775109303371},
#  {'Train_Function': 'y4', 'Ideal_Function': 'y50', 'MSE': 0.500129766627665}]

# %%
function_selector.save_result_SQLite_db()
data_visualizer.summerize_db()
# Out:
# The table 'MSE' has been deleted.
# Table: train, Rows: 400, Columns: 5
# Table: test, Rows: 100, Columns: 2
# Table: ideal, Rows: 400, Columns: 51
# Table: MSE, Rows: 200, Columns: 3

# %% [markdown]
# <div style="color:#FBDC8A; font-family: Calibri; font-size: 16pt; text-align: center;">
#      <strong>Let's apply minimum MSE selection function.<strong> </div>

# %%
function_selector.list_minimum_MSE()
# Out:
# Train_Function: y1, Ideal_Function: y42, MinMSE: 0.08561648575842126
# Train_Function: y2, Ideal_Function: y41, MinMSE: 0.0890046173120288
# Train_Function: y3, Ideal_Function: y11, MinMSE: 0.07465457572540955
# Train_Function: y4, Ideal_Function: y48, MinMSE: 0.07990858581972925

# %% [markdown]
# <div style="color:#FBDC8A; font-family: Calibri; font-size: 16pt; text-align: center;">
#      <strong>Let's have a look at the curves of the selected functions (f11, f41, f42, f48) that we have created previously for ideal functions and training functions fit.<strong> </div>

# %% [markdown]
# ![Alt text](bokeh_plot(3).png)

# %% [markdown]
# <div style="color:#FBDC8A; font-family: Calibri; font-size: 16pt; text-align: center;">
#      <strong>Using test dataset to verify the results and calculate deviations.<strong> </div>
